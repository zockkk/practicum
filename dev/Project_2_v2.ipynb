# %% [markdown]
# <div class="alert alert-success">
# <font size="4"><b>Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#     Привет, Станислав :) Спасибо, что прислал задание 🤝 Меня зовут Ринат Хисамов и я буду проверять твой проект. Предлагаю обращаться друг к другу на ты. Так нам будет гораздо проще и удобней общаться
#
# Мои комментарии обозначены пометкой <b>Комментарий ревьюера</b>. Далее в файле сможешь найти их в похожих ячейках (если фон комментария зелёный — всё сделано правильно (✔️), рекомендации таким же цветом. Отдельным цветом — блок ссылок (примеры ниже, 🍕). Оранжевым или светло желтым рекомендации, которые, хоть и не обязательны, но точно сделают ревью лучше. (⚠️); <u> красный комментарий</u>: код, график или вывод стоит переделать (❌)).
#
# Не удаляй все эти комментарии и постарайся учесть их в ходе выполнения данного проекта.
# Будет замечательно, если добавишь свои комментарии и пояснения✍
#
# Поехали 🚀
#     <br />
#     </font>
#
# </div>

# %% [markdown]
# <div style="border:solid steelblue 1px; padding: 20px">
#
# <font size="4"><p style="text-align:center"><b>Примеры комментариев </b></p></font>
#
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4"><b>🍕 Пример комментария - совета, здесь м.б. просто ссылка</b></font>
#     <br />
#         <font size="3", color = "black">
# <br />
#     Тут всего такого разного и вкусного :), есть способы прокачать проект визуализациями (ценит большинство "боссов")  <br /><br />
#         <a href="https://devpractice.ru/matplotlib-book/">“Библиотека Matplotlib” доступна для скачивания БЕСПЛАТНО!</a>
#         На сайте много полезных материалов, мне самому очень помогло в свое время, до сих пор подсматриваю :)
#
#
# </div>
#
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
#     <font size="3"><b>⚠️ Пример оформления некритичного комментария</b>
#     <br />
#     <font size="2", color = "black">
# <br />
#     Рекомендации, которые, хоть и не обязательны, но точно сделают ревью лучше
#     <br />
#     </font>
#
# </div>
#
# <div class="alert alert-danger">
# <font size="3"><b>❌ Пример оформления комментария к блоку(строке) программного кода (или выводу), который стоит переделать</b></font>
#     <br />
#     <font size="2", color = "black">
# <br />
#     Отправлен не тот проект, напиши в своих комментариях, что случилось? жду — <b>это пример</b>
#     <br />
#     </font>
#
# </div>
#
# <div class="alert alert-success">
# <font size="4"><b>✔️ Пример оформления комментария, который нравится большинству студентов</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#     Круто, молодец, отлично, логично, или — 👌, 👍, или — выводы отвечают на все вопросы к данным и проекту
#     <br />
#     </font>
#
# </div>

# %% [markdown]
# # Для твоих вопросов или комментариев оставлю такую ячейку, чтобы было удобнее взаимодействовать на проекте

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> ... , вот мой вопрос ...

# %% [markdown]
# # Проект 2: Исследоватльский анализ данных

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# Четкий план работ и перечень основных задач позволит коллегам быстрее вникнуть в суть проекта, + будет легче идти к главной цели проекта — стоит добавить

# %% [markdown]
# ## План
#
# 1. Получить общие сведения о данных. Узнать обьем данных, количество пропусков, какие данные хранятся в колонках и каких они типов.
# 2. Узнать причину пропусков в данных. Обработать пропуски, где это возможно. Изменить типы данных некоторых колонок на более подходящие. Обработать дубликаты.
# 3. Добавить новые категориальные столбцы.
# 4. Провести исследование данных. Обнарущить аномалии и выбросы в данных. Исследовать скорость продажы квартир. Исследовать параметры влияющие на стоимость. Найти среднюю цену за кв.м. Найти зависимость стоимости квартиры от расстояния до центра города в СПб.
# 5. Написать общий вывод.

# %%
import pandas as pd

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Молодец, что делишь блоки загрузки библиотек и датасета, в случае необходимости добавления новых библиотек не придется загружать весь датасет заново и перезапускать проект целиком

# %% [markdown]
# ## Общие сведения о данных

# %%
try:
    data = pd.read_csv('../datasets/real_estate_data.csv', sep='\t')
except:
    data = pd.read_csv('/datasets/real_estate_data.csv', sep='\t')
data.head(10)
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0      108.00  2019-03-07T00:00:00      3
# 1             7   3350000.0       40.40  2018-12-04T00:00:00      1
# 2            10   5196000.0       56.00  2015-08-20T00:00:00      2
# 3             0  64900000.0      159.00  2015-07-24T00:00:00      3
# 4             2  10000000.0      100.00  2018-06-19T00:00:00      2
# 5            10   2890000.0       30.40  2018-09-10T00:00:00      1
# 6             6   3700000.0       37.30  2017-11-02T00:00:00      1
# 7             5   7915000.0       71.60  2019-04-18T00:00:00      2
# 8            20   2900000.0       33.16  2018-05-23T00:00:00      1
# 9            18   5400000.0       61.00  2017-02-26T00:00:00      3
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70          16.0        51.00      8          NaN  ...
# 1             NaN          11.0        18.60      1          NaN  ...
# ...

# %% [markdown]
# ### Общая информация о данных

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %%
data.hist(figsize=(15, 20));

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />
# Убрать служ. информацию поможет точка с запятой на посл. строке кода
#
#     array([[<AxesSubplot:title={'center':'total_images'}>,
#         <AxesSubplot:title={'center':'last_price'}>,
#         <AxesSubplot:title={'center':'total_area'}>,
#         <AxesSubplot:title={'center':'rooms'}>],
#        [<AxesSubplot:title={'center':'ceiling_height'}>,
#         <AxesSubplot:title={'center':'floors_total'}>,
#         <AxesSubplot:title={'center':'living_area'}>,
#         <AxesSubplot:title={'center':'floor'}>],
#        [<AxesSubplot:title={'center':'kitchen_area'}>,
#         <AxesSubplot:title={'center':'balcony'}>,
#         <AxesSubplot:title={'center':'airports_nearest'}>,
#         <AxesSubplot:title={'center':'cityCenters_nearest'}>],
#        [<AxesSubplot:title={'center':'parks_around3000'}>,
#         <AxesSubplot:title={'center':'parks_nearest'}>,
#         <AxesSubplot:title={'center':'ponds_around3000'}>,
#         <AxesSubplot:title={'center':'ponds_nearest'}>],
#        [<AxesSubplot:title={'center':'days_exposition'}>, <AxesSubplot:>,
#         <AxesSubplot:>, <AxesSubplot:>]], dtype=object)
#
# data.hist(figsize=(15, 20));

# %% [markdown]
# ### Пропуски в колонках.

# %%
data.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           9195
# floors_total               86
# living_area              1903
# floor                       0
# is_apartment            20924
# studio                      0
# open_plan                   0
# kitchen_area             2278
# balcony                 11519
# locality_name              49
# airports_nearest         5542
# cityCenters_nearest      5519
# parks_around3000         5518
# parks_nearest           15620
# ponds_around3000         5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64

# %% [markdown]
# В таблице 14 колонок имеют пропуски, причем в некоторых колонках пропущено до 90% значений.
#
# * Пропущенные значения в колонке ceiling_height можно заченить медианным значением.
# * Пропуски в колонках living_area, kitchen_area заменим медианой по количеству комнат.
# * Пропуски в колонке с количеством балконов заменим на 0.
# * Пропуски в колонке is_apartment нужно оставить как есть, сейчас неясно как их устранить и эти данные не влияют на результаты исследования.
# * Пропуски в колонках locality_name, cityCenters_nearest заполним медианным значением, а parks_around3000, ponds_around3000 - нулями.

# %%
# check
# пропущенные значения бары

def pass_value_barh(df):
    try:
        (
            (df.isna().mean()*100)
            .to_frame()
            .rename(columns={0:'space'})
            .query('space > 0')
            .sort_values(by='space', ascending=True)
            .plot(kind='barh', figsize=(19,6), legend=False, fontsize=16)
            .set_title('Пример' + "\n", fontsize=22, color='SteelBlue')    
        );    
    except:
        print('пропусков не осталось :) или произошла ошибка в первой части функции ')

# %%
pass_value_barh(data)

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br /> Наглядность представления информации одна из важных составляющих работы дата-аналитика или дата-сайентиста
#
# __мой график оформлен не совсем корректно, сможешь отметить, что стоило бы исправить в графике?__

# %% [markdown]
# #### Возможные причины пропусков

# %%
display(data['ceiling_height'].isna().sum())
data['ceiling_height'].value_counts()
# Out:
# 9195
# ceiling_height
# 2.50    3515
# 2.60    1646
# 2.70    1574
# 3.00    1112
# 2.80     993
#         ...
# 5.00       1
# 2.20       1
# 2.34       1
# 3.93       1
# 3.59       1
# Name: count, Length: 183, dtype: int64

# %% [markdown]
# Потеряно больше 9000 значений. Возможно некоторые люди не указывают высоту полотков или часть данных была утеряна при техническом сбое. Вместо пропусков целесообразно вставить медианное значение.

# %%
display(data['floors_total'].isna().sum())
data['floors_total'].value_counts()
# Out:
# 86
# floors_total
# 5.0     5788
# 9.0     3761
# 16.0    1376
# 12.0    1362
# 4.0     1200
# 10.0    1174
# 25.0    1075
# 6.0      914
# 17.0     833
# 3.0      668
# 7.0      592
# 14.0     553
# 18.0     505
# 24.0     469
# 8.0      390
# 2.0      383
# 15.0     365
# 23.0     352
# 19.0     339
# 22.0     286
# 20.0     271
# 13.0     229
# 11.0     203
# 27.0     164
# 21.0     158
# 26.0     124
# 1.0       25
# 35.0      24
# 28.0      21
# 36.0       3
# 34.0       1
# 60.0       1
# 29.0       1
# 33.0       1
# 52.0       1
# 37.0       1
# Name: count, dtype: int64

# %% [markdown]
# Небольшая часть значений потеряна. Пропуски можно модой по текущему этажу. Также нужно изменить тип данных на целочисленный.

# %%
display(data['living_area'].isna().sum())
data['living_area'].value_counts()
# Out:
# 1903
# living_area
# 18.00     882
# 17.00     675
# 30.00     598
# 16.00     486
# 20.00     481
#          ...
# 76.70       1
# 39.41       1
# 124.90      1
# 36.07       1
# 42.55       1
# Name: count, Length: 1782, dtype: int64

# %% [markdown]
# Примерно 9% данных утеряно. Их можно восстановить медианой по количеству комнат. Причиной пропусков может служить технический сбой или нежелание людей указывать жилую площадь.

# %%
display(data['is_apartment'].isna().sum())
data['is_apartment'].value_counts()
# Out:
# 20924
# is_apartment
# False    2725
# True       50
# Name: count, dtype: int64

# %% [markdown]
# Почти 90% данных утеряно. Такие данные тяжело восстановить, их проще оставить как есть, тем более они не повлияют на результат исследования.

# %%
display(data['kitchen_area'].isna().sum())
data['kitchen_area'].value_counts()
# Out:
# 2278
# kitchen_area
# 6.00     1300
# 10.00    1262
# 8.00     1110
# 9.00     1101
# 7.00     1062
#          ...
# 53.10       1
# 12.56       1
# 11.84       1
# 13.27       1
# 13.83       1
# Name: count, Length: 971, dtype: int64

# %% [markdown]
# Примерно 10% данных утеряно. Пропуски можно заполнить медианой. Причины прокусков могут быть такими же как и в столбце с жилой слощадью.

# %%
display(data['balcony'].isna().sum())
data['balcony'].value_counts()
# Out:
# 11519
# balcony
# 1.0    4195
# 0.0    3758
# 2.0    3659
# 5.0     304
# 4.0     183
# 3.0      81
# Name: count, dtype: int64

# %% [markdown]
# Половина значений утеряна. Пропущенные значения скорее всего указывают на отсутствие балкона. Такие пропуски следует заполнить нулями.

# %%
display(data['locality_name'].isna().sum())
data['locality_name'].value_counts()
# Out:
# 49
# locality_name
# Санкт-Петербург                    15721
# посёлок Мурино                       522
# посёлок Шушары                       440
# Всеволожск                           398
# Пушкин                               369
#                                    ...
# поселок Каложицы                       1
# посёлок Платформа 69-й километр        1
# поселок Почап                          1
# поселок Гончарово                      1
# посёлок Дзержинского                   1
# Name: count, Length: 364, dtype: int64

# %% [markdown]
# Утеряно меньше 1% данных. Пропуски можно заполнить например значением 'неопределён' либо убрать эти строки из выборки.

# %%
data.loc[~(data['airports_nearest'].isna())].loc[:, 'airports_nearest': 'ponds_nearest'].isna().sum()
# Out:
# airports_nearest           0
# cityCenters_nearest        1
# parks_around3000           0
# parks_nearest          10098
# ponds_around3000           0
# ponds_nearest           9055
# dtype: int64

# %% [markdown]
# В колонках airports_nearest, cityCenters_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest значения отсутствуют в одинаковых строках, видимо программа не смогла правильно расчитать расстояние до центра, либо чать данных была утеряна при передача либо данных геолокации не хватило для правильного расчета значений.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> обзор данных проведен корректно

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# #### Приведение столбцов к единому стилю

# %%
data = data.rename(columns={
    'cityCenters_nearest' : 'city_center_nearest'
})

# %% [markdown]
# #### Убираем слишком большие значения в столбце с высотой потолков
#
# Значения больше 20м скорее всего указаны на десяток больше чем есть на самом деле (такие значения разделим на 10), строки со значениями от 10м до 20м просто удалим (их всего 2).

# %%
data['ceiling_height'].unique()
# Out:
# array([  2.7 ,    nan,   3.03,   2.5 ,   2.67,   2.56,   3.05,   2.75,
#          2.6 ,   2.9 ,   2.8 ,   2.55,   3.  ,   2.65,   3.2 ,   2.61,
#          3.25,   3.45,   2.77,   2.85,   2.64,   2.57,   4.15,   3.5 ,
#          3.3 ,   2.71,   4.  ,   2.47,   2.73,   2.84,   3.1 ,   2.34,
#          3.4 ,   3.06,   2.72,   2.54,   2.51,   2.78,   2.76,  25.  ,
#          2.58,   3.7 ,   2.52,   5.2 ,   2.87,   2.66,   2.59,   2.  ,
#          2.45,   3.6 ,   2.92,   3.11,   3.13,   3.8 ,   3.15,   3.55,
#          3.16,   3.62,   3.12,   2.53,   2.74,   2.96,   2.46,   5.3 ,
#          5.  ,   2.79,   2.95,   4.06,   2.94,   3.82,   3.54,   3.53,
#          2.83,   4.7 ,   2.4 ,   3.38,   3.01,   5.6 ,   3.65,   3.9 ,
#          3.18,   3.35,   2.3 ,   3.57,   2.48,   2.62,   2.82,   3.98,
#          2.63,   3.83,   3.52,   3.95,   3.75,   2.88,   3.67,   3.87,
#          3.66,   3.85,   3.86,   4.19,   3.24,   4.8 ,   4.5 ,   4.2 ,
# ...

# %%
data.loc[(data['ceiling_height'] == 14.) | (data['ceiling_height'] == 10.3), 'ceiling_height'].count()
# Out:
# 2

# %%
data = data[(data['ceiling_height'] != 14.) & (data['ceiling_height'] != 10.3)]
data.loc[data['ceiling_height'] > 20, 'ceiling_height'] /= 10

# %%
data['ceiling_height'] = data['ceiling_height'].fillna(data['ceiling_height'].median())

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит учитывать физическое распределение данных, в разных районах Питера высота потолков разная
#
# ... если рассмотреть районность высоты потолков, т.к. в современных районах Питера высота потолков будет ожидаема ниже, чем в исторических, мы увидим, что заполнение подобного объема пропусков медианой или средним значением «размажет» это отличительное свойство объектов недвижимости в центре Питера
#
# [Обработка пропусков в данных](https://loginom.ru/blog/missing)

# %% [markdown]
# #### Заменяем пропуски в колонках ponds_around3000, parks_around3000 и balcony на нули.

# %%
data['parks_around3000'] = data['parks_around3000'].fillna(0)
data['ponds_around3000'] = data['ponds_around3000'].fillna(0)
data['balcony'] = data['balcony'].fillna(0)
display(data['balcony'].value_counts())
display(data['parks_around3000'].value_counts())
data['ponds_around3000'].value_counts()
# Out:
# balcony
# 0.0    15276
# 1.0     4195
# 2.0     3658
# 5.0      304
# 4.0      183
# 3.0       81
# Name: count, dtype: int64
# parks_around3000
# 0.0    15623
# 1.0     5681
# 2.0     1746
# 3.0      647
# Name: count, dtype: int64
# ponds_around3000
# 0.0    14588
# 1.0     5717
# 2.0     1891
# 3.0     1501
# Name: count, dtype: int64

# %% [markdown]
# #### Заполняем пропуски в колонке living_area медианой по количеству комнат.
#
# Количество комнат больше всего влияет на жилую площадь.

# %%
display(data['living_area'].value_counts())
for t in data['rooms'].unique():
    data.loc[(data['rooms'] == t) & (data['living_area'].isna()), 'living_area'] = \
    data.loc[(data['rooms'] == t), 'living_area'].median()
display(data['living_area'].isna().sum())
# Out:
# living_area
# 18.00     882
# 17.00     675
# 30.00     598
# 16.00     486
# 20.00     481
#          ...
# 76.70       1
# 39.41       1
# 124.90      1
# 36.07       1
# 42.55       1
# Name: count, Length: 1782, dtype: int64
# 0

# %% [markdown]
# #### Заполняем пропуски в колонке количества этажей модой по этажу квартиры.

# %%
for t in data['floor'].unique():
    data.loc[(data['floor'] == t) & (data['floors_total'].isna()), 'floors_total'] = \
    data.loc[(data['floor'] == t), 'floors_total'].mode()[0]
display(data['floors_total'].value_counts())
# Проверка на корректность значений
display((data['floors_total'] < data['floor']).sum())
data['floors_total'].isna().sum()
# Out:
# floors_total
# 5.0     5811
# 9.0     3787
# 16.0    1383
# 12.0    1371
# 4.0     1200
# 10.0    1177
# 25.0    1089
# 6.0      914
# 17.0     833
# 3.0      668
# 7.0      592
# 14.0     552
# 18.0     508
# 24.0     469
# 8.0      390
# 2.0      383
# 15.0     365
# 23.0     352
# 19.0     339
# 22.0     286
# 20.0     271
# 13.0     229
# 11.0     203
# 27.0     164
# 21.0     158
# 26.0     124
# 1.0       25
# 35.0      24
# 28.0      21
# 36.0       3
# 34.0       1
# 60.0       1
# 29.0       1
# 33.0       1
# 52.0       1
# 37.0       1
# Name: count, dtype: int64
# 0
# 0

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Для красоты («продаваемости») всего проекта не стоит выходить за видимую ширину тетради юпитер ноутбука, коллеги ценят удобство прочтения кода. Широкие строки кода рекомендуется — делить <a href="https://qastack.ru/programming/53162/how-can-i-do-a-line-break-line-continuation-in-python">Перенос длинных строк кода</a>.
#
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />После заполнения синтетическими данными, стоит провести проверку на корректность значений по условию (этажность дома не м.б. ниже этажности квартиры)
#
#     ['floors_total'] < ['floor']

# %% [markdown]
# #### Заполняем пропуски в колонке с площадью кухни синтетическими значениями

# %%
# Проверка на аномалии до заполнения синтетическими значениями
display(data.query('total_area*0.9 > (living_area + kitchen_area)').count())
data['kitchen_area'] = data['kitchen_area'].fillna(data['total_area'] * 0.9 - data['living_area']) 
# Проверка на аномалии после заполнения синтетическими значениями
display(data.query('total_area*0.9 > (living_area + kitchen_area)').count())
display(data['kitchen_area'].value_counts())
data['kitchen_area'].isna().sum()
# Out:
# total_images            20915
# last_price              20915
# total_area              20915
# first_day_exposition    20915
# rooms                   20915
# ceiling_height          20915
# floors_total            20915
# living_area             20915
# floor                   20915
# is_apartment             2517
# studio                  20915
# open_plan               20915
# kitchen_area            20915
# balcony                 20915
# locality_name           20875
# airports_nearest        16238
# city_center_nearest     16259
# parks_around3000        20915
# parks_nearest            7205
# ponds_around3000        20915
# ponds_nearest            8076
# days_exposition         18022
# dtype: int64
# total_images            20917
# last_price              20917
# total_area              20917
# first_day_exposition    20917
# rooms                   20917
# ceiling_height          20917
# floors_total            20917
# living_area             20917
# ...

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />После заполнения синтетическими данными столбцов, стоит провести проверку на корректность значений всех наших площадей, т.к. есть коридоры, сан.узлы, балконы — на них отводим условные 10% площади
#
#         total_area*0.9 <= (living_area + kitchen_area)
#
# если алгоритм заполнения пропусков приводит к появлению аномалий, стоит подумать над его содержимым
#
#     Для решения задачи можно использовать запросы с query

# %% [markdown]
# #### Заколняем прокуски в имени локации значением 'неопределена'

# %%
data['locality_name'] = data['locality_name'].fillna('Неопределена')
display(data['locality_name'].value_counts())
data['locality_name'].isna().sum()
# Out:
# locality_name
# Санкт-Петербург                   15719
# посёлок Мурино                      522
# посёлок Шушары                      440
# Всеволожск                          398
# Пушкин                              369
#                                   ...
# поселок Гладкое                       1
# посёлок городского типа Рябово        1
# поселок Цвылёво                       1
# поселок городского типа Рябово        1
# посёлок Дзержинского                  1
# Name: count, Length: 365, dtype: int64
# 0

# %% [markdown]
# #### Заполняем пропуски в колонках airports_nearest, city_center_nearest, parks_nearest, ponds_nearest медианой для каждого столбца

# %%
for t in ['airports_nearest', 'city_center_nearest', 'parks_nearest', 'ponds_nearest']:
    display(data.loc[data[t].isna(), 'locality_name'].value_counts())
# Out:
# locality_name
# посёлок Мурино                     522
# Всеволожск                         398
# Гатчина                            307
# деревня Кудрово                    299
# Выборг                             237
#                                   ...
# деревня Пельгора                     1
# поселок Каложицы                     1
# посёлок Платформа 69-й километр      1
# поселок Почап                        1
# посёлок Дзержинского                 1
# Name: count, Length: 345, dtype: int64
# locality_name
# посёлок Мурино          522
# Всеволожск              398
# Гатчина                 307
# деревня Кудрово         299
# Выборг                  237
#                        ...
# деревня Щеглово           1
# посёлок Алексеевка        1
# деревня Пельгора          1
# поселок Каложицы          1
# посёлок Дзержинского      1
# Name: count, Length: 346, dtype: int64
# locality_name
# Санкт-Петербург                   8436
# посёлок Мурино                     522
# ...

# %%
for t in ['airports_nearest', 'city_center_nearest', 'parks_nearest', 'ponds_nearest']:
    display(data.loc[~(data[t].isna()), 'locality_name'].value_counts())
# Out:
# locality_name
# Санкт-Петербург            15634
# посёлок Шушары               436
# Пушкин                       369
# Колпино                      337
# посёлок Парголово            327
# Петергоф                     201
# Сестрорецк                   183
# Красное Село                 176
# Ломоносов                    132
# Кронштадт                     95
# посёлок Металлострой          66
# посёлок Стрельна              44
# Неопределена                  41
# Павловск                      38
# Зеленогорск                   24
# посёлок Понтонный             20
# посёлок Сапёрный               6
# посёлок Молодёжное             5
# посёлок Песочный               4
# посёлок Репино                 4
# посёлок Александровская        2
# поселок Мурино                 2
# посёлок Лисий Нос              2
# посёлок Усть-Ижора             2
# посёлок Петро-Славянка         1
# посёлок Щеглово                1
# поселок Лисий Нос              1
# посёлок Левашово               1
# ...

# %% [markdown]
# В колонках 'airports_nearest', 'city_center_nearest', 'parks_nearest', 'ponds_nearest' данные пропущены для одних и тех же населенных пунктов (в колонках 'parks_nearest', 'ponds_nearest' также отсутствуют данные по Санкт-Петербургу).
# Пропуски в колонках 'airports_nearest', 'city_center_nearest' могут повлиять на результаты исследования (пропусков больше 10%)

# %%
for t in ['airports_nearest', 'city_center_nearest', 'parks_nearest', 'ponds_nearest']:
    data[t] = data[t].fillna(data[t].median())
data.loc[:, ['airports_nearest', 'city_center_nearest', 'parks_nearest', 'ponds_nearest']].isna().sum()
# Out:
# airports_nearest       0
# city_center_nearest    0
# parks_nearest          0
# ponds_nearest          0
# dtype: int64

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Не изучено распределение пропусков по городам до заполнения значений в ['city_сenters_nearest' и в 'airports_nearest']
#
# к каким населенным пунктам относятся пропуски и самое важное — нет оценки степени влияния пропусков на дальнейший анализ (будут мешать выполнить проект или нет )

# %% [markdown]
# #### Пропуски в 'days_exposition' говорят, что квартиры не проданы, эти пропуски оставляем.

# %%
#data['days_exposition'] = data['days_exposition'].fillna(data['days_exposition'].mean())
#data['days_exposition'].isna().sum()

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Пропуски в ['days_exposition'] говорят нам, что квартиры еще не проданы..., неверно терять столь важный признак, → оставляем пропуски

# %% [markdown]
# #### Изменяем типы данных в колонках, где это необходимо

# %% [markdown]
# Ещё раз откроем общую информацию о данных.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 23697 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23697 non-null  int64
#  1   last_price            23697 non-null  float64
#  2   total_area            23697 non-null  float64
#  3   first_day_exposition  23697 non-null  object
#  4   rooms                 23697 non-null  int64
#  5   ceiling_height        23697 non-null  float64
#  6   floors_total          23697 non-null  float64
#  7   living_area           23697 non-null  float64
#  8   floor                 23697 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23697 non-null  bool
#  11  open_plan             23697 non-null  bool
#  12  kitchen_area          23697 non-null  float64
#  13  balcony               23697 non-null  float64
#  14  locality_name         23697 non-null  object
# ...

# %%
data.head(10)
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0      108.00  2019-03-07T00:00:00      3
# 1             7   3350000.0       40.40  2018-12-04T00:00:00      1
# 2            10   5196000.0       56.00  2015-08-20T00:00:00      2
# 3             0  64900000.0      159.00  2015-07-24T00:00:00      3
# 4             2  10000000.0      100.00  2018-06-19T00:00:00      2
# 5            10   2890000.0       30.40  2018-09-10T00:00:00      1
# 6             6   3700000.0       37.30  2017-11-02T00:00:00      1
# 7             5   7915000.0       71.60  2019-04-18T00:00:00      2
# 8            20   2900000.0       33.16  2018-05-23T00:00:00      1
# 9            18   5400000.0       61.00  2017-02-26T00:00:00      3
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70          16.0        51.00      8          NaN  ...
# 1            2.65          11.0        18.60      1          NaN  ...
# ...

# %% [markdown]
# * Колонки last_price, floors_total, balcony, parks_around3000, ponds_around3000, days_exposition имеют тип float хотя хранят целочисленные значения. В целях экономии памяти лучше изменить тип этих колонок на int.
# * Значения в колонке first_day_exposition для убодства работы преобразуем в тип datetime.
# * Значения в столбце is_apartament имеют значения True и False, но имеют тип object. В целях экономии памяти лучше изменить тип этих колонок на bool.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Классная автоматизация ⬇⬇⬇, молодец

# %%
for t in ['last_price', 'floors_total', 'balcony', 'parks_around3000', 'ponds_around3000']:
    data[t] = data[t].astype('int')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 23697 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23697 non-null  int64
#  1   last_price            23697 non-null  int32
#  2   total_area            23697 non-null  float64
#  3   first_day_exposition  23697 non-null  object
#  4   rooms                 23697 non-null  int64
#  5   ceiling_height        23697 non-null  float64
#  6   floors_total          23697 non-null  int32
#  7   living_area           23697 non-null  float64
#  8   floor                 23697 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23697 non-null  bool
#  11  open_plan             23697 non-null  bool
#  12  kitchen_area          23697 non-null  float64
#  13  balcony               23697 non-null  int32
#  14  locality_name         23697 non-null  object
# ...

# %%
data['first_day_exposition'] = pd.to_datetime(data['first_day_exposition'], format='%Y-%m-%dT%H:%M:%S')
data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20    13000000       108.0           2019-03-07      3
# 1             7     3350000        40.4           2018-12-04      1
# 2            10     5196000        56.0           2015-08-20      2
# 3             0    64900000       159.0           2015-07-24      3
# 4             2    10000000       100.0           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70            16         51.0      8          NaN  ...
# 1            2.65            11         18.6      1          NaN  ...
# 2            2.65             5         34.3      4          NaN  ...
# 3            2.65            14         45.0      9          NaN  ...
# 4            3.03            14         32.0     13          NaN  ...
#
#    kitchen_area  balcony    locality_name  airports_nearest  \
# 0          25.0        0  Санкт-Петербург           18863.0
# ...

# %%
data['is_apartment'] = data['is_apartment'].astype('bool')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 23697 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23697 non-null  int64
#  1   last_price            23697 non-null  int32
#  2   total_area            23697 non-null  float64
#  3   first_day_exposition  23697 non-null  datetime64[ns]
#  4   rooms                 23697 non-null  int64
#  5   ceiling_height        23697 non-null  float64
#  6   floors_total          23697 non-null  int32
#  7   living_area           23697 non-null  float64
#  8   floor                 23697 non-null  int64
#  9   is_apartment          23697 non-null  bool
#  10  studio                23697 non-null  bool
#  11  open_plan             23697 non-null  bool
#  12  kitchen_area          23697 non-null  float64
#  13  balcony               23697 non-null  int32
#  14  locality_name         23697 non-null  object
# ...

# %% [markdown]
# После изменения типов данные стало удобнее читать и они занимают меньше памяти.

# %% [markdown]
# ### Работа с дубликатамм

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Явных дубликатов в данных нет.
# Неявные могут находиться в колонке с названиями населённых пунктов.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Проверка на поиск дубликатов выполнена, молодец
#
# Особенно это станет важным, когда мы перейдем к более сложным задачам на втором модуле курса
#
# __Стоит выполнять повторный поиск после обработки неявных дубликатов__

# %%
data['locality_name'].value_counts()
# Out:
# locality_name
# Санкт-Петербург                   15719
# посёлок Мурино                      522
# посёлок Шушары                      440
# Всеволожск                          398
# Пушкин                              369
#                                   ...
# поселок Гладкое                       1
# посёлок городского типа Рябово        1
# поселок Цвылёво                       1
# поселок городского типа Рябово        1
# посёлок Дзержинского                  1
# Name: count, Length: 365, dtype: int64

# %%
data['new_locality_name'] = (
    data['locality_name']
    .str.replace('ё','е')
    .replace(['поселок\sгородского\sтипа+', 'городской\sпоселок+'], 'поселок', regex=True)
)
display(data['new_locality_name'].value_counts())
data['new_locality_name'].unique()
# Out:
# new_locality_name
# Санкт-Петербург                    15719
# поселок Мурино                       556
# поселок Шушары                       440
# Всеволожск                           398
# Пушкин                               369
#                                    ...
# поселок Белоостров                     1
# деревня Пельгора                       1
# поселок Каложицы                       1
# поселок Платформа 69-й километр        1
# поселок Дзержинского                   1
# Name: count, Length: 323, dtype: int64
# array(['Санкт-Петербург', 'поселок Шушары', 'поселок Янино-1',
#        'поселок Парголово', 'поселок Мурино', 'Ломоносов', 'Сертолово',
#        'Петергоф', 'Пушкин', 'деревня Кудрово', 'Коммунар', 'Колпино',
#        'поселок Красный Бор', 'Гатчина', 'деревня Федоровское', 'Выборг',
#        'Кронштадт', 'Кировск', 'деревня Новое Девяткино',
#        'поселок Металлострой', 'поселок Лебяжье', 'поселок Сиверский',
# ...

# %% [markdown]
# Изменены дублирующиеся значения 'посёлок городского типа', 'посёлок', 'поселок городского типа', 'поселок' на просто 'поселок', также убраны все беквы ё во избежание дубликатов.

# %% [markdown]
# #### check name

# %%
# check
data.new_locality_name.nunique()
# Out:
# 323

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Хорошая работа по избавлению от неявных дубликатов
#
# Можно отметить в отчете — стоит ли объединять нас. пункты
#
#         'деревня Кудрово'
#         'Кудрово'

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# + дополнительно — на рабочих проектах стоит искать дубликаты по сумме ключевых параметров (подмножеству), для примера:
#
#  + общ. площадь квартиры,
#  + этаж,
#  + общая этажность дома,
#  + расстояние до центра
#  + название населенного пункта
#  + кол-во комнат
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.duplicated.html?highlight=duplicat#pandas.DataFrame.duplicated
#
# https://www.codecamp.ru/blog/pandas-find-duplicates/

# %% [markdown]
# ### Проверка остальных колонок

# %%
data['total_images'].value_counts()
# Out:
# total_images
# 10    1798
# 9     1725
# 20    1693
# 8     1585
# 7     1521
# 6     1482
# 11    1362
# 5     1301
# 12    1225
# 0     1059
# 13    1015
# 4      986
# 14     986
# 15     948
# 1      872
# 3      769
# 16     761
# 17     650
# 18     642
# 2      640
# 19     602
# 23      16
# 21      12
# 24       8
# 22       8
# 26       5
# 32       4
# 28       4
# 50       3
# 29       3
# 27       2
# 30       2
# 35       2
# 31       2
# 42       1
# 25       1
# 39       1
# 37       1
# Name: count, dtype: int64

# %%
data['total_area'].value_counts()
# Out:
# total_area
# 45.00     418
# 42.00     383
# 60.00     347
# 31.00     346
# 44.00     345
#          ...
# 184.40      1
# 55.64       1
# 56.16       1
# 109.10      1
# 76.75       1
# Name: count, Length: 2182, dtype: int64

# %%
data['last_price'].value_counts()
# Out:
# last_price
# 4500000     342
# 3500000     291
# 4300000     260
# 4000000     260
# 4200000     259
#            ...
# 12890000      1
# 29375000      1
# 7545600       1
# 5205000       1
# 11475000      1
# Name: count, Length: 2978, dtype: int64

# %%
data['total_area'].value_counts()
# Out:
# total_area
# 45.00     418
# 42.00     383
# 60.00     347
# 31.00     346
# 44.00     345
#          ...
# 184.40      1
# 55.64       1
# 56.16       1
# 109.10      1
# 76.75       1
# Name: count, Length: 2182, dtype: int64

# %%
data['first_day_exposition'].value_counts()
# Out:
# first_day_exposition
# 2018-02-01    368
# 2017-11-10    240
# 2017-10-13    124
# 2017-09-27    111
# 2018-03-26     97
#              ...
# 2018-05-20      1
# 2015-05-15      1
# 2015-01-12      1
# 2015-12-19      1
# 2015-07-19      1
# Name: count, Length: 1491, dtype: int64

# %%
data['rooms'].value_counts()
# Out:
# rooms
# 1     8046
# 2     7939
# 3     5814
# 4     1180
# 5      326
# 0      197
# 6      105
# 7       59
# 8       12
# 9        8
# 10       3
# 11       2
# 14       2
# 15       1
# 19       1
# 16       1
# 12       1
# Name: count, dtype: int64

# %%
data['floor'].value_counts()
# Out:
# floor
# 2     3368
# 3     3073
# 1     2917
# 4     2804
# 5     2620
# 6     1305
# 7     1218
# 8     1083
# 9     1051
# 10     687
# 12     526
# 11     523
# 13     379
# 15     342
# 14     337
# 16     315
# 17     227
# 18     178
# 19     147
# 21     125
# 22     113
# 20     110
# 23     100
# 24      63
# 25      46
# 26      24
# 27      10
# 28       1
# 30       1
# 29       1
# 32       1
# 33       1
# 31       1
# Name: count, dtype: int64

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит добавить короткий вывод по результатам выполнения раздела проекта

# %% [markdown]
# * В данных 14 колонок имели пропуски. Во всех колонках кроме is_apartament, days_exposition удалось заполнить пропуски не испортив статистику:
#     * в колонке с высотой потолка не хватало более 9000 значений. Возможно некоторые люди не указывают высоту полотков или часть данных была утеряна при техническом сбое. Пропуски были заполнены медианой имеющихся значений.
#     * в колонке с количеством этажей небольшая часть значений потеряна. Пропуски были заполнены модой по текущему этажу.
#     * в колонке жилой площади примерно 9% данных утеряно. Эти данные были заполнены медианой по количеству комнат. Причиной пропусков может служить технический сбой или нежелание людей указывать жилую площадь.
#     * в колонке с полщадью кухни примерно 10% данных утеряно. Пропуски были заполнены значением 'total_area'*0.9 - 'living_area'. Причины прокусков могут быть такими же как и в столбце с жилой слощадью.
#     * в колонке с количеством балконов половина значений утеряна. Пропущенные значения скорее всего указывают на отсутствие балкона. Такие пропуски были заполнены нулями.
#     * в колонке названия населенного пункта утеряно меньше 1% данных. Пропуски были заполнены значением "необределен".
#     * в колонках airports_nearest, cityCenters_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest значения отсутствуют в одинаковых строках (в одних и тех же населенных пунктах), видимо часть людей не заполнила эти данные, либо они были утеряны при техническом сбое.
#         * в колонках airports_nearest, cityCenters_nearest, parks_nearest, ponds_nearest пропуски были заполнены медианой.
#         * в колонках parks_around3000, ponds_around3000 - нулями.
#     * в колонке days_exposition пропуски не были заполнены так как они указывают на то, что квартинра еще не продана.
#
# * В колонке с названиями населенных пунктов были обработаны неявные дубликаты, например, "посёлок Молодцово" и "поселок Молодцово".
# * В колонке с высотой потолка были обработаны аномалии, например, высота потолка 25 метров. Такие значения скорее всего имели неправельный разделитель целочисленной части и были поделены на 10. значения от 10м до 20м были удалены.
# * В колонках 'last_price', 'floors_total', 'balcony', 'parks_around3000', 'ponds_around3000' был изменент тип данных на целочисленный
# * В колонке first_day_exposition тип был изменен на datetime для удобства работы с этой колонкой.

# %% [markdown]
# ## Добавление новых столбцов

# %% [markdown]
# ##### Добавлен столбец с ценой за квадратный метр

# %%
data['price_per_squre_meter'] = (data['last_price'] / data['total_area']).round(2)
data['price_per_squre_meter']
# Out:
# 0        120370.37
# 1         82920.79
# 2         92785.71
# 3        408176.10
# 4        100000.00
#            ...
# 23694     72490.85
# 23695     52542.37
# 23696     44091.71
# 23697    149511.40
# 23698     41795.67
# Name: price_per_squre_meter, Length: 23697, dtype: float64

# %% [markdown]
# ##### Добавлены столбцы с днем недели, месяцем и годом публикации обьявления

# %%
data['day_of_the_week'] = data['first_day_exposition'].dt.weekday
data['month_exposition'] = data['first_day_exposition'].dt.month
data['year_exposition'] = data['first_day_exposition'].dt.year
display(data['day_of_the_week'].value_counts())
display(data['month_exposition'].value_counts())
data['year_exposition'].value_counts()
# Out:
# day_of_the_week
# 3    4295
# 1    4183
# 4    3999
# 2    3974
# 0    3612
# 5    1935
# 6    1699
# Name: count, dtype: int64
# month_exposition
# 2     2640
# 3     2587
# 4     2379
# 11    2371
# 10    2127
# 9     1980
# 6     1760
# 8     1744
# 7     1695
# 12    1641
# 1     1500
# 5     1273
# Name: count, dtype: int64
# year_exposition
# 2018    8518
# 2017    8189
# 2019    2879
# 2016    2783
# 2015    1191
# 2014     137
# Name: count, dtype: int64

# %% [markdown]
# ##### Добавлена колонка с категорией этажа

# %%
# функция для категорелизации экажей
def floor_type(row):
    if row['floor'] == 1:
        return 'первый'
    elif row['floor'] == row['floors_total']:
        return 'последний'
    elif row['floor'] != 1 and row['floor'] != row['floors_total']:
        return 'другой'
    else: 
        return 'ошибка'

data['floor_category'] = data.apply(floor_type, axis=1)
data['floor_category'].value_counts()
# Out:
# floor_category
# другой       17423
# последний     3357
# первый        2917
# Name: count, dtype: int64

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Функция хорошая, стоит учесть крайние условия: возможные нулевые и отрицательные значения

# %% [markdown]
# ##### Добавлена колонка с расстоянием до центра города в км

# %%
data['city_center_nearest_km'] = (data['city_center_nearest'] / 1000).round().astype('int')
data['city_center_nearest_km'].value_counts()
# Out:
# city_center_nearest_km
# 13    6976
# 12    1606
# 15    1568
# 14    1278
# 16    1265
#       ...
# 62       1
# 59       1
# 45       1
# 61       1
# 63       1
# Name: count, Length: 61, dtype: int64

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> данные добавлены корректно, молодец

# %% [markdown]
# ## Исследовательский анализ

# %%
data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20    13000000       108.0           2019-03-07      3
# 1             7     3350000        40.4           2018-12-04      1
# 2            10     5196000        56.0           2015-08-20      2
# 3             0    64900000       159.0           2015-07-24      3
# 4             2    10000000       100.0           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0            2.70            16         51.0      8          True  ...
# 1            2.65            11         18.6      1          True  ...
# 2            2.65             5         34.3      4          True  ...
# 3            2.65            14         45.0      9          True  ...
# 4            3.03            14         32.0     13          True  ...
#
#    ponds_around3000  ponds_nearest  days_exposition  new_locality_name  \
# ...

# %% [markdown]
# #### Общие наблюдения

# %%
data.plot(y='total_area', 
          kind='hist', 
          grid=True, 
          figsize=(12,6), 
          bins=200, 
          range=(0, 250)
         ).set_title('Общая площадь' + "\n", fontsize=20, color='SteelBlue');

# %%
display(data['living_area'].value_counts())
data.plot(y='living_area', 
          kind='hist', 
          grid=True, 
          figsize=(12,6), 
          bins=200, 
          range=(0, 250)
         ).set_title('Жилая площадь' + "\n", fontsize=20, color='SteelBlue');
# Out:
# living_area
# 18.00     896
# 17.60     755
# 30.50     710
# 17.00     675
# 30.00     598
#          ...
# 76.70       1
# 39.41       1
# 124.90      1
# 36.07       1
# 42.55       1
# Name: count, Length: 1783, dtype: int64

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Хорошие графики, можно увеличить кол-во корзин у  гистограмм
#
# Подписи осей на графиках и название добавят ясности и читабельности.
# Это важные элементы любой визуализации. Как добавить подписи и названия, смотри [здесь](https://proproprogs.ru/modules/matplotlib-razmeshchaem-standartnye-tekstovye-elementy-na-grafike?ysclid=l6agtioc6f299002507)
#
# Стоит полностью оформить все графики

# %%
data.plot(y='kitchen_area', 
          kind='hist', 
          grid=True, 
          figsize=(12,6),
          bins=200, 
          range=(0, 60)
         ).set_title('Площадь кухни' + "\n", fontsize=20, color='SteelBlue');

# %%
data.plot(y='last_price', 
          kind='hist', 
          grid=True, 
          figsize=(12,6), 
          bins=200, 
          range=(0,5e7)
         ).set_title('Стоимость' + "\n", fontsize=20, color='SteelBlue');

# %%
data['rooms'].value_counts().plot.bar().set_title('Количество комнат' + "\n", fontsize=20, color='SteelBlue');

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />  Стоит изменить параметры отображения гистограммы (добавить кол-во корзин), сейчас трудно определить типовое кол-во комнат

# %%
data.plot(y='ceiling_height', 
          kind='hist', 
          grid=True, 
          figsize=(12,6), 
          range=(2,5), 
          bins=200
         ).set_title('Высота потолков' + "\n", fontsize=20, color='SteelBlue');

# %%
data['floor_category'].value_counts().plot.bar().set_title('Этаж' + "\n", fontsize=20, color='SteelBlue');

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Стоит  добавить график

# %%
data.plot(y='floors_total', 
          kind='hist', 
          grid=True, 
          figsize=(12,6), 
          bins=200, 
          range=(0,40)
         ).set_title('Всего этажей в доме' + "\n", fontsize=20, color='SteelBlue');

# %%
data.plot(y='city_center_nearest', 
          kind='hist', 
          grid=True, 
          figsize=(12,6), 
          bins=100
         ).set_title('Расстояние до центра города' + "\n", fontsize=20, color='SteelBlue');

# %%
data.plot(y='parks_nearest', 
          kind='hist', 
          grid=True, 
          figsize=(12,6), 
          bins=100
         ).set_title('Расстояние до ближайшего парка' + "\n", fontsize=20, color='SteelBlue');

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> При отрисовке графиков стоит временно исключать значения-заглушки (если они корректные), которыми мы заполнили пропуски, они мешают рассматривать реальную картину

# %% [markdown]
# * Все колонки, кроме floors_total и living_area, имеют вид очень похожий на распределение Пуассона (колонки-исключения имеют впадины на графике. В колонке floors_total это обусловленно тем, что большая часть домов имеют либо 5, либо 9, либо 13, либо 15 этажей в силу ГОСТов при постройке этих зданий. на графике колонки living_area также наблюдаются несколько пиков, что скорее всего также обусловленно ГОСТами времен постройки)
# * Во всех колонках, кроме rooms и ceiling_height видны выбросы (в колонке ceiling_height аномальные значения были заранее преобразованы)

# %% [markdown]
# #### check gap

# %%
# check
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 23697 entries, 0 to 23698
# Data columns (total 29 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   total_images            23697 non-null  int64
#  1   last_price              23697 non-null  int32
#  2   total_area              23697 non-null  float64
#  3   first_day_exposition    23697 non-null  datetime64[ns]
#  4   rooms                   23697 non-null  int64
#  5   ceiling_height          23697 non-null  float64
#  6   floors_total            23697 non-null  int32
#  7   living_area             23697 non-null  float64
#  8   floor                   23697 non-null  int64
#  9   is_apartment            23697 non-null  bool
#  10  studio                  23697 non-null  bool
#  11  open_plan               23697 non-null  bool
#  12  kitchen_area            23697 non-null  float64
#  13  balcony                 23697 non-null  int32
# ...

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# __проверим какие аномалии остались__ таблица ниже

# %%
# check

# Показатели о кол-ве объявлений в датасете, минимальных и максимальных значениях 
# в выбранных параметрах о продаже квартир

(
    data[['rooms', 'total_area', 'ceiling_height', 'days_exposition', 'last_price', 'living_area',  'kitchen_area',
          'floor', 'floors_total']]
    .apply (['count', 'min', 'max', 'median'])   
    .style.format("{:,.2f}")
)
# Out:
# <style type="text/css">
# </style>
# <table id="T_21ef4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_21ef4_level0_col0" class="col_heading level0 col0" >rooms</th>
#       <th id="T_21ef4_level0_col1" class="col_heading level0 col1" >total_area</th>
#       <th id="T_21ef4_level0_col2" class="col_heading level0 col2" >ceiling_height</th>
#       <th id="T_21ef4_level0_col3" class="col_heading level0 col3" >days_exposition</th>
#       <th id="T_21ef4_level0_col4" class="col_heading level0 col4" >last_price</th>
#       <th id="T_21ef4_level0_col5" class="col_heading level0 col5" >living_area</th>
#       <th id="T_21ef4_level0_col6" class="col_heading level0 col6" >kitchen_area</th>
#       <th id="T_21ef4_level0_col7" class="col_heading level0 col7" >floor</th>
#       <th id="T_21ef4_level0_col8" class="col_heading level0 col8" >floors_total</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />остались аномалии и редкости (в т.ч. и хвосты) в колонках:
#
#         'rooms', 'total_area', 'ceiling_height', 'days_exposition', 'last_price', 'living_area',  'kitchen_area', 'floors_total'
#
# стоит обратить внимание на минимальные и максимальные значения в выборке и учесть наличие пропусков при фильтрации данных

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Доп. задание, на твое усмотрение — сможешь добавить в таблицу расчет медианного значения?
#
#         (
#             data[['rooms', 'total_area', 'ceiling_height', 'days_exposition', 'last_price', 'living_area',  'kitchen_area',
#                   'floor', 'floors_total']]
#             .apply (['count', 'min', 'max'])
#             .style.format("{:,.2f}")
#         )

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Для выполнения пункта 4.1. (или в старой версии п.2.4) существует два подхода
#
# Можно механически бороться с выбросами (при помощи межквартильного размаха), ...
#
# основная проблема такого подхода — не учитывается неоднородность нашей выборки: у нас здесь и малые поселки, и вторая столица страны, и исторический фонд и массовая застройка, и однушки и довольно большое кол-во многокомнатных квартир, или наоборот одна две квартиры с количеством комнат больше 7-ми ...
#
#
#
# если бы у нас в таблице были бы только однокомнатные квартиры из определенного района массовой застройки, тогда да, мы бы боролись с выбросами традиционными способами, при нашем многообразии населенных пунктов, многокомнатности такие подходы не работают... т.е. они работают, но это усложнит наш проект — придется разбить и объединить записи нашей таблицы по нескольким параметрам (кол-во комнат, район, и т.д.), а затем только выполнять все остальные пункты на каждой отдельной выборке
#
# Остается другой подход — убираем редкие значения и следим за количеством потерь...
#
# Для выборки из 23-х тысяч значений, несколько записей со стоимостью квадратного метра выше 1-го млн. руб., довольно редкое явление
#
# Хороший пример, высота потолков, которую мы отрезаем по нижней и верхней планке, это скорее аномальные записи, посмотрим на другой аспект — на редкости: кол-во комнат
#
# __т.е. мы не говорим о том, что квартир с кол-ом комнат выше 7 не бывает, мы говорим, что для нашего исследования это редкие выбивающиеся из общей картины уникальные объекты, по которым необходимо проводить отдельную работу ...__
#
# подобным образом рассматриваем и остальные параметры
#
# наши помощники
#
# 1. гистограммы, с хорошим масштабом
# 2. метод describe() или облегченная версия, пример выше
# 3. метод value_counts()
#
# плюс жизненный опыт

# %%
# check

try:
    df_check = pd.read_csv('https://code.s3.yandex.net/datasets/real_estate_data.csv', sep='\t')
# если не получилось прочитать файл из локальной папки, то загружаем данные из сети
except:
    df_check = pd.read_csv('real_estate_data.csv', sep='\t')

# %%
# check
df_check.rooms.value_counts().to_frame()
# Out:
#        count
# rooms
# 1       8047
# 2       7940
# 3       5814
# 4       1180
# 5        326
# 0        197
# 6        105
# 7         59
# 8         12
# 9          8
# 10         3
# 11         2
# 14         2
# 15         1
# 19         1
# 16         1
# 12         1

# %%
# check
df_check.total_area.hist(bins = 150, figsize = (15,3));

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />т.е. все квартиры менее 20-ти и более 250-ти квадратных метров можно считать редкостями

# %%
# check
df_check.total_area.hist(bins = 150, figsize = (15,3), range = (180,500));

# %%
# check
df_check.total_area.hist(bins = 15, figsize = (15,3), range = (180,500));

# %%
# check
df_check.total_area.hist(bins = 15, figsize = (15,3), range = (0,25));

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Осталось завершить выполнение пункта 4.1 из брифа проекта (в старой версии п.2.4)
#
# В некоторых параметрах встречаются редкие и выбивающиеся значения. При построении гистограмм удалите их. Например, в столбце ceiling_height может быть указана высота потолков 25 м и 32 м. Логично предположить, что на самом деле это вещественные значения: 2.5 м и 3.2 м. Попробуйте обработать аномалии в этом и других столбцах, если они есть. Если природа аномалии понятна и данные действительно искажены, то восстановите    корректное значение. В противном случае удалите редкие и выбивающиеся значения.
#
# __Критичный уровень потерь записей на этапе предобработки составляет 10%, оптимальный 5%__
#
# Если при фильтрации одной колонки, на этом проекте, теряем больше одного процента данных от изначального объема, стоит еще раз пересмотреть условия фильтрации

# %%
# check

# Значения параметров объектов недвижимости на разных квантилях

(
    data[['rooms', 'total_area', 'ceiling_height', 'days_exposition', 'last_price', 'living_area',  
        'kitchen_area', 'floor',   'floors_total']]
    .quantile([0.0012, 0.01, .5, .99, .9988]) # выбираем размах в 0,9976 квантилей 
    .style.format("{:,.2f}")
)
# Out:
# <style type="text/css">
# </style>
# <table id="T_e4cc0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e4cc0_level0_col0" class="col_heading level0 col0" >rooms</th>
#       <th id="T_e4cc0_level0_col1" class="col_heading level0 col1" >total_area</th>
#       <th id="T_e4cc0_level0_col2" class="col_heading level0 col2" >ceiling_height</th>
#       <th id="T_e4cc0_level0_col3" class="col_heading level0 col3" >days_exposition</th>
#       <th id="T_e4cc0_level0_col4" class="col_heading level0 col4" >last_price</th>
#       <th id="T_e4cc0_level0_col5" class="col_heading level0 col5" >living_area</th>
#       <th id="T_e4cc0_level0_col6" class="col_heading level0 col6" >kitchen_area</th>
#       <th id="T_e4cc0_level0_col7" class="col_heading level0 col7" >floor</th>
#       <th id="T_e4cc0_level0_col8" class="col_heading level0 col8" >floors_total</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера </b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Квантили что это такое (первая ссылка иногда не открывается)
#
# https://fin-accounting.ru/cfa/l1/quantitative/cfa-quartiles-quintiles-deciles-percentiles?ysclid=l7gy2kky4i156375632
#
# https://www.codecamp.ru/blog/percentile-vs-quartile-vs-quantile/?ysclid=lg89wjm4zz267333250
#
# они помогают увидеть редкости и аномалии в данных

# %% [markdown]
# #### Скорость продажи

# %% [markdown]
# Отсекаем редкие значения в колонках 'rooms', 'total_area', 'ceiling_height', 'days_exposition', 'last_price', 'living_area', 'kitchen_area', 'floor', 'floors_total'

# %%
data_new = data[(data['rooms'] >= 1) & (data['rooms'] <= 8)]
data_new = data_new[(data_new['total_area'] >= 20) & (data_new['total_area'] <= 200)]
data_new = data_new[(data_new['ceiling_height'] >= 2.4) & (data_new['ceiling_height'] <= 4.4)]
data_new = data_new[(data_new['last_price'] >= 5e5) & (data_new['last_price'] <= 124e6)]
data_new = data_new[(data_new['living_area'] >= 10) & (data_new['living_area'] <= 200)]
data_new['kitchen_area'] = data_new['kitchen_area'].abs()
data_new = data_new[(data_new['kitchen_area'] >= 4) & (data_new['kitchen_area'] <= 100)]
data_new = data_new[(data_new['floor'] >= 1) & (data_new['floor'] <= 26)]
data_new = data_new[(data_new['floors_total'] >= 2) & (data_new['floors_total'] <= 35)]
display(data['rooms'].count())
data_new['rooms'].count()
# Out:
# 23697
# 23019

# %% [markdown]
# После отсечения редких значений было потеряно менее 5% данных.

# %%
display(data_new['days_exposition'].describe());
display(data_new.groupby('year_exposition')['days_exposition'].describe());
display(data_new.boxplot(column='days_exposition', vert=False, figsize=(8,2)));
data_new.plot(y='days_exposition', kind='hist', grid=True, figsize=(8,4), bins=50);
# Out:
# count    19938.000000
# mean       180.747818
# std        219.148880
# min          1.000000
# 25%         45.000000
# 50%         96.000000
# 75%        231.000000
# max       1580.000000
# Name: days_exposition, dtype: float64
#                   count        mean         std    min     25%    50%     75%  \
# year_exposition
# 2014              114.0  917.421053  299.044315  554.0  607.25  893.5  1139.0
# 2015             1085.0  645.815668  318.267069  182.0  388.00  571.0   880.0
# 2016             2657.0  319.985698  255.883737    3.0  114.00  234.0   474.0
# 2017             7670.0  159.207823  153.093296    3.0   45.00  103.0   227.0
# 2018             7356.0   94.388254   85.054700    3.0   34.00   64.0   131.0
# 2019             1056.0   31.068182   23.961484    1.0   12.00   23.0    45.0
#
#                     max
# year_exposition
# 2014             1580.0
# 2015             1512.0
# 2016             1153.0
# 2017              814.0
# 2018              465.0
# ...

# %% [markdown]
# Продажа квартиры обычно занимает от 45 до 200 дней. При быстрой продаже квартиры продаются до 45 дней, а необычно долгой можно считать продажу длительностью дольше 400 дней.
# Если смотреть на данные по годам можно сказать, что время продажы снижается с каждым годом.

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит пересчитать статистики скорости продажи после восстановления пропусков

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
#
# __Интересно посмотреть на изменение средней  скорости продаж по годам__

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Не исследованы моды (пиковые значения) в 'days_exposition' и как они влияют на скорость продажи, подсказка на что смотреть
#
# [Условия размещения объявлений](https://yandex.ru/support/realty/owner/home/add-ads-housing.html)

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br /> Компактность графика

# %%
# check
import matplotlib.pyplot as plt

# %%
# check
# для примера горизонтальный вид диаграммы размаха

fig, ax = plt.subplots(figsize=(17,2))
ax = data[['total_area']].boxplot(vert=False, ax=ax)
ax.set_title('Диаграмма размаха значений площади')
ax.set_xlim(0, 400);

# %% [markdown]
# #### Параметры, влияющие на строимость

# %%
display(data_new['total_area'].corr(data_new['last_price']))
data_new.plot(x='total_area', 
          y='last_price', 
          kind='scatter', 
          figsize=(12,6),
          alpha=0.3
         ).set_title('Стоимость от общей площади' + "\n", fontsize=20, color='SteelBlue');
# Out:
# 0.7225799768175266

# %%
display(data_new['living_area'].corr(data_new['last_price']))
data_new.plot(x='living_area', 
          y='last_price', 
          kind='scatter', 
          figsize=(12,6),
          alpha=0.3
         ).set_title('Стоимость от жилой площади' + "\n", fontsize=20, color='SteelBlue');
# Out:
# 0.5875577356722597

# %%
display(data_new['kitchen_area'].corr(data_new['last_price']))
data_new.plot(x='kitchen_area', 
          y='last_price', 
          kind='scatter', 
          figsize=(12,6),
          alpha=0.3
         ).set_title('Стоимость от площади кухни' + "\n", fontsize=20, color='SteelBlue');
# Out:
# 0.5219503514931974

# %% [markdown]
# На графиках видна некоторая зависимость цены от площади и для всех трех факторов коэффициент корреляции близок к 0.5. (Встречаются выбросы, например, высокая цена при маленькой площади и наоборот)

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />  Можно попробовать настроить вид точечных графиков
#
# [Как сделать диаграмму рассеяния из фрейма данных Pandas](https://www.codecamp.ru/blog/pandas-scatter-plot/?ysclid=lh0tbpkoa9628147030)
#
# Примеры расчета коэф. корреляции и не только
#
# [Исследуем отношение между переменными](https://dfedorov.spb.ru/pandas/downey/%D0%98%D1%81%D1%81%D0%BB%D0%B5%D0%B4%D1%83%D0%B5%D0%BC%20%D0%BE%D1%82%D0%BD%D0%BE%D1%88%D0%B5%D0%BD%D0%B8%D0%B5%20%D0%BC%D0%B5%D0%B6%D0%B4%D1%83%20%D0%BF%D0%B5%D1%80%D0%B5%D0%BC%D0%B5%D0%BD%D0%BD%D1%8B%D0%BC%D0%B8.html?ysclid=l9ev0utyg728177057)
#
# [Примеры графиков](https://proglib.io/p/kollekciya-prodvinutoy-vizualizacii-v-matplotlib-i-seaborn-s-primerami-2021-02-11?ysclid=ltnocrlmos378496858)

# %%
rooms = data_new.pivot_table(index='rooms', values='last_price', aggfunc=['median', 'count', 'mean'])
rooms.columns = ['median_price', 'count', 'mean']
# отсечем малочисленные группы составляющие меньше 5% от всей выборки так как они содержат выбросы
rooms = rooms.loc[(rooms.index > 0) & (rooms.index < 6)]
display(rooms.style.format("{:,.0f}"))
display(rooms.describe().style.format("{:,.0f}"))
rooms.plot(y='median_price', style='o-')
# Out:
# <style type="text/css">
# </style>
# <table id="T_5056d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5056d_level0_col0" class="col_heading level0 col0" >median_price</th>
#       <th id="T_5056d_level0_col1" class="col_heading level0 col1" >count</th>
#       <th id="T_5056d_level0_col2" class="col_heading level0 col2" >mean</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >rooms</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5056d_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_5056d_row0_col0" class="data row0 col0" >3,600,000</td>
#       <td id="T_5056d_row0_col1" class="data row0 col1" >7,919</td>
#       <td id="T_5056d_row0_col2" class="data row0 col2" >3,846,156</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# На графике видно, что количество комнат влияет на стоимость. Чем больше комнат тем дороже квартира.

# %%
years = data_new.pivot_table(index='year_exposition', values='last_price', aggfunc=['median', 'count', 'mean'])
years.columns = ['median_price', 'count', 'mean']
# отсекаем года с низким количеством обьявлений
years = years.loc[years.index > 2015]
display(years.style.format("{:,.0f}"))
years.plot(y='median_price', style='o-')
# Out:
# <style type="text/css">
# </style>
# <table id="T_0992c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0992c_level0_col0" class="col_heading level0 col0" >median_price</th>
#       <th id="T_0992c_level0_col1" class="col_heading level0 col1" >count</th>
#       <th id="T_0992c_level0_col2" class="col_heading level0 col2" >mean</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >year_exposition</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0992c_level0_row0" class="row_heading level0 row0" >2016</th>
#       <td id="T_0992c_row0_col0" class="data row0 col0" >4,500,000</td>
#       <td id="T_0992c_row0_col1" class="data row0 col1" >2,722</td>
#       <td id="T_0992c_row0_col2" class="data row0 col2" >6,116,759</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# График проказывает, что в 2019 году стоимость выросла, хотя год вряд ли является причиной увеличения цены, скорее всего повлияли какие-то другие факторы.

# %%
years_table = data_new.pivot_table(
    index='year_exposition',
    values=['last_price', 'total_area'],
    aggfunc=['median', 'count', 'mean'])
years_table.columns = ['last_price_median', 'total_area_median', 'count1', 'count2', 'last_price_mean', 'total_area_mean']
display(years_table.style.format("{:,.0f}"))
years_table.plot(y='last_price_median', 
           x='total_area_median',
           style='o-').set_title('Стоимость от площади по годам' + "\n", fontsize=20, color='SteelBlue');
# Out:
# <style type="text/css">
# </style>
# <table id="T_c57e3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c57e3_level0_col0" class="col_heading level0 col0" >last_price_median</th>
#       <th id="T_c57e3_level0_col1" class="col_heading level0 col1" >total_area_median</th>
#       <th id="T_c57e3_level0_col2" class="col_heading level0 col2" >count1</th>
#       <th id="T_c57e3_level0_col3" class="col_heading level0 col3" >count2</th>
#       <th id="T_c57e3_level0_col4" class="col_heading level0 col4" >last_price_mean</th>
#       <th id="T_c57e3_level0_col5" class="col_heading level0 col5" >total_area_mean</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >year_exposition</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
# ...

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит дополнить  вывод об изменении цен по годам, необходимо учесть другие факторы, которые также изменяются с годами: площадь и кол-во объявлений о продаже (стоит добавить или графики, или сводные таблицы и исследовать взаимное влияние параметров: кол-во записей и изменение средней цены и средней площади в течение лет)
#
#         в этом пункте самое главное создать таблицы с сгруппированнами данными, при помощи группировки или сводных таблиц
#
# Одна из таблиц у тебя уже готова — об изменении кол-ва объявлений по годам, осталось добавить информацию про изменение средней площади

# %%
month = data_new.pivot_table(
    index='month_exposition', 
    values=['last_price', 'total_area'], 
    aggfunc=['median', 'count', 'mean'])
month.columns = ['last_price_median', 'total_area_median', 'count1', 'count2', 'last_price_mean', 'total_area_mean']
display(month.style.format("{:,.0f}"))
display(month['last_price_median'].corr(month['total_area_median']))
month.plot(y='last_price_median', style='o-')
# Out:
# <style type="text/css">
# </style>
# <table id="T_a1f0a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a1f0a_level0_col0" class="col_heading level0 col0" >last_price_median</th>
#       <th id="T_a1f0a_level0_col1" class="col_heading level0 col1" >total_area_median</th>
#       <th id="T_a1f0a_level0_col2" class="col_heading level0 col2" >count1</th>
#       <th id="T_a1f0a_level0_col3" class="col_heading level0 col3" >count2</th>
#       <th id="T_a1f0a_level0_col4" class="col_heading level0 col4" >last_price_mean</th>
#       <th id="T_a1f0a_level0_col5" class="col_heading level0 col5" >total_area_mean</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >month_exposition</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
# ...

# %% [markdown]
# Впадины на этом графике коррелируют с медианой общей слощади.

# %%
day = data_new.pivot_table(
    index='day_of_the_week', 
    values=['last_price', 'total_area'], 
    aggfunc=['median', 'count', 'mean'])
day.columns = ['last_price_median', 'total_area_median', 'count1', 'count2', 'last_price_mean', 'total_area_mean']
display(day.style.format("{:,.0f}"))
day.plot(y='last_price_median', style='o-')
# Out:
# <style type="text/css">
# </style>
# <table id="T_43bc4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_43bc4_level0_col0" class="col_heading level0 col0" >last_price_median</th>
#       <th id="T_43bc4_level0_col1" class="col_heading level0 col1" >total_area_median</th>
#       <th id="T_43bc4_level0_col2" class="col_heading level0 col2" >count1</th>
#       <th id="T_43bc4_level0_col3" class="col_heading level0 col3" >count2</th>
#       <th id="T_43bc4_level0_col4" class="col_heading level0 col4" >last_price_mean</th>
#       <th id="T_43bc4_level0_col5" class="col_heading level0 col5" >total_area_mean</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >day_of_the_week</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
# ...

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера </b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
#
# Интересно, по какой причине средние цены в выходные настолько отличаются от средних цен в будние дни (100-150 тыс. руб.)?

# %%
floor_category = data.pivot_table(
    index='floor_category', 
    values='last_price', 
    aggfunc=['median', 'count', 'mean']
)
floor_category.columns = ['median_price', 'count', 'mean']
display(floor_category)
floor_category.plot(y='median_price', style='o-')
# Out:
#                 median_price  count          mean
# floor_category
# другой               4850000  17423  6.675779e+06
# первый               3900000   2917  4.803560e+06
# последний            4300000   3357  7.355729e+06
# <Axes: xlabel='floor_category'>

# %% [markdown]
# Можно заметить, что первый этаж имеет самую низкую стоимость а не первый и не последний самую высокую.

# %% [markdown]
# #### Средняя цена на кв.м.

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Широкие строки кода рекомендуется делить на всем проекте
#
# <a href="https://qastack.ru/programming/53162/how-can-i-do-a-line-break-line-continuation-in-python">Перенос длинных строк кода</a>.
#
# </div>

# %%
locality = data.pivot_table(
    index='new_locality_name', 
    values=['last_price', 'total_area'], 
    aggfunc=['count', 'mean'])
locality.columns = ['count', 'count1', 'last_price', 'total_area']
locality = locality.drop('count1', axis=1).sort_values(by='count', ascending=False)[0:10]
locality['avg_price_sq_m'] = (locality['last_price'] / locality['total_area']).round(2)
display(locality.sort_values(by='avg_price_sq_m', ascending=False).style.format("{:,.0f}"))
locality.sort_values(by='avg_price_sq_m', ascending=False)['avg_price_sq_m'].plot.bar()
# Out:
# <style type="text/css">
# </style>
# <table id="T_8b88a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8b88a_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_8b88a_level0_col1" class="col_heading level0 col1" >last_price</th>
#       <th id="T_8b88a_level0_col2" class="col_heading level0 col2" >total_area</th>
#       <th id="T_8b88a_level0_col3" class="col_heading level0 col3" >avg_price_sq_m</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >new_locality_name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8b88a_level0_row0" class="row_heading level0 row0" >Санкт-Петербург</th>
#       <td id="T_8b88a_row0_col0" class="data row0 col0" >15,719</td>
# ...

# %% [markdown]
# * Самая высокая стоимость квадратного метра в Санкт-Петербурге: 124516 за квадратный метр.
# * Самая низкая стоимлсть квадратного метра в Выборге: 57898 за квадратный метр.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />ТОП-10 рассчитан корректно

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Недостаточно найти числа, стоит их показать красиво, удобно и наглядно, чтобы одного взгляда хватило, где самые самые, а где подешевле 📊

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />
#
# [Постер поможет выбирать вид графиков](https://www.notion.so/6c5ae8ceb8b5411e907c93c9b5e6a44e)

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> на проектах стоит снижать размерность выводимой информации, где не требуется максимальная точность, до одного или двух знаков после запятой
#
#        деревня Кудрово	299	4.234158e+06	46.571739

# %% [markdown]
# #### Зависимость стоимости квартиры в СПб от расстояния до центра города

# %%
sankt_peterburg = data_new.query('locality_name == "Санкт-Петербург"')
sankt_peterburg = sankt_peterburg.pivot_table(index='city_center_nearest_km', 
                                              values=['last_price', 'total_area', 'floor', 'rooms', 'floors_total'], 
                                              aggfunc='mean')

display(sankt_peterburg.style.format("{:,.0f}"))
sankt_peterburg.plot(y='last_price', style='o-')
# Out:
# <style type="text/css">
# </style>
# <table id="T_54fed">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_54fed_level0_col0" class="col_heading level0 col0" >floor</th>
#       <th id="T_54fed_level0_col1" class="col_heading level0 col1" >floors_total</th>
#       <th id="T_54fed_level0_col2" class="col_heading level0 col2" >last_price</th>
#       <th id="T_54fed_level0_col3" class="col_heading level0 col3" >rooms</th>
#       <th id="T_54fed_level0_col4" class="col_heading level0 col4" >total_area</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >city_center_nearest_km</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_54fed_level0_row0" class="row_heading level0 row0" >0</th>
# ...

# %% [markdown]
# Стоимость обьектов падает в с ростом расстояния до центра города.

# %%
data_new.query('locality_name == "Санкт-Петербург" and city_center_nearest_km == 27')
# Out:
#       total_images  last_price  total_area first_day_exposition  rooms  \
# 748             13    14350000        74.0           2017-11-28      2
# 5961             6     2250000        32.0           2018-02-27      1
#
#       ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 748             3.13             5         30.0      3          True  ...
# 5961            2.65             2         16.5      2          True  ...
#
#       ponds_around3000  ponds_nearest  days_exposition  new_locality_name  \
# 748                  0          502.0            128.0    Санкт-Петербург
# 5961                 0          502.0            178.0    Санкт-Петербург
#
#      price_per_squre_meter  day_of_the_week  month_exposition  \
# 748              193918.92                1                11
# 5961              70312.50                1                 2
#
#       year_exposition  floor_category  city_center_nearest_km
# ...

# %% [markdown]
# В силу малого числа данных и большого разброса значений в колоке стоимости получился выброс на 27-м километре.

# %%
data_new.query('locality_name == "Санкт-Петербург"')\
.pivot_table(index=['floor_category','city_center_nearest_km'], values='last_price', aggfunc='mean')\
.style.format('{:,.0f}')
# Out:
# <style type="text/css">
# </style>
# <table id="T_5b7b7">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5b7b7_level0_col0" class="col_heading level0 col0" >last_price</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >floor_category</th>
#       <th class="index_name level1" >city_center_nearest_km</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5b7b7_level0_row0" class="row_heading level0 row0" rowspan="30">другой</th>
#       <th id="T_5b7b7_level1_row0" class="row_heading level1 row0" >0</th>
#       <td id="T_5b7b7_row0_col0" class="data row0 col0" >25,400,170</td>
#     </tr>
#     <tr>
#       <th id="T_5b7b7_level1_row1" class="row_heading level1 row1" >1</th>
#       <td id="T_5b7b7_row1_col0" class="data row1 col0" >13,924,815</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# Независимо от этажа стоимость с 4 по 8 километр растет. Клиичество комнат и общая площадь также не обьясняет роста цены.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Молодец, у тебя получилось сгруппировать и построить график изменения средней цены в зависимости от расстояния до центра

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Стоит изучить записи, которые привели к выбросу на 27-м км.

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Стоит посмотреть на количество квартир разных категорий (первый, последний, другой), которые продаются на 3-м км. и 5-ом ... и какую долю они занимают на каждом километре, чтобы объяснить пик  и провал в центре
#
#         выполняется при помощи группировки или свода данных

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# ### Проблемы в данных и их решения
#
# * В данных 14 колонок имели пропуски. Во всех колонках кроме is_apartament удалось заполнить пропуски не испортив статистику:
#     * в колонке с высотой потолка не хватало более 9000 значений. Возможно некоторые люди не указывают высоту полотков или часть данных была утеряна при техническом сбое. Пропуски были заполнены медианой имеющихся значений.
#     * в колонке с количеством этажей небольшая часть значений потеряна. Пропуски были заполнены модой по текущему этажу.
#     * в колонке жилой площади примерно 9% данных утеряно. Эти данные были заполнены медианой по количеству комнат. Причиной пропусков может служить технический сбой или нежелание людей указывать жилую площадь.
#     * в колонке с полщадью кухни примерно 10% данных утеряно. Пропуски были заполнены медианой. Причины прокусков могут быть такими же как и в столбце с жилой слощадью.
#     * в колонке с количеством балконов половина значений утеряна. Пропущенные значения скорее всего указывают на отсутствие балкона. Такие пропуски были заполнены нулями.
#     * в колонке названия населенного пункта утеряно меньше 1% данных. Пропуски были заполнены значением "необределен".
#     * в колонках airports_nearest, cityCenters_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest значения отсутствуют в одинаковых строках, видимо часть людей не заполнила эти данные, либо они были утеряны при техническом сбое.
#         * в колонках airports_nearest, cityCenters_nearest, parks_nearest, ponds_nearest пропуски были заполнены медианой.
#         * в колонках parks_around3000, ponds_around3000 - нулями.
#     * в колонке days_exposition пропуски были оставлены.
#
# * В колонке с названиями населенных пунктов были обработаны неявные дубликаты, например, "посёлок Молодцово" и "поселок Молодцово".
# * В колонке с высотой потолка были обработаны аномалии, например, высота потолка 25 метров. Такие значения скорее всего имели неправельный разделитель целочисленной части и были поделены на 10. значения от 10м до 20м были удалены.
# * В колонках 'last_price', 'floors_total', 'balcony', 'parks_around3000', 'ponds_around3000' был изменент тип данных на целочисленный
# * В колонке days_exposition тип был изменен на datetime для удобства работы с этой колонкой.
#
# ### Основные выводы
#
# #### Общий вид данных
#
# * Все графики колонок, кроме floors_total и living_area, имеют вид очень похожий на распределение Пуассона (колонки-исключения имеют впадины на графике. В колонке floors_total это обусловленно тем, что большая часть домов имеют либо 5, либо 9, либо 13, либо 15 этажей в силу ГОСТов при постройке этих зданий. на графике колонки living_area также наблюдаются несколько пиков, что скорее всего также обусловленно ГОСТами времен постройки)
# * Во всех колонках, кроме rooms и ceiling_height видны выбросы (в колонке ceiling_height аномальные значения были заранее преобразованы)
#
# ##### Были убраны редкие значения сильно отличающиеся от остальных
#
# #### Скорость продажи квартиры
#
# * Продажа квартиры обычно занимает от 45 до 222 дней. При быстрой продаже квартиры продаются до 45 дней, а необычно долгой можно считать продажу длительностью дольше 450 дней.
#
# #### Параметры, влияющие на стоимость
#
# * Были выявлены зависимости стоимости от количества комнат, общей площади, жилой площади и площади кухни. (Кореляция больше 0.5)
# * На графиках также можно заметить небольшую зависимость стоимости от дня недели, месяца и года (что по большей части обусловленно общей площадью).
# * Была выявлена зависимость от этажа, на котором расположена квартира: первый этаж самый дешевый, а не первый и не последний имеет самую высокую стоимость.
# * Исследование покзало следующий рост зависимостей: меньше всего стоимость зависит от времени публикации обьявления, далее идут площади кухни, жилой зоны, общая площадь и тип этажа и больше всего стоимость зависит от количества комнат.
#
# #### Средняя цена квадратного метра в 10 самых популярных населенных пунктах
#
# * Самая высокая стоимость квадратного метра в Санкт-Петербурге: 124516 за квадратный метр.
# * Самая низкая стоимлсть квадратного метра в Выборге: 57898 за квадратный метр.
#
# #### Зависимость стоимости от расстояния до центра в СПб
#
# * Стоимость обьектов в Санкт-Петербурге падает в с ростом расстояния до центра города. В самом центре города стоимость составляет около 30 000 000, в 5 км. от центра примерно 15 000 000, а в 10 км - 6 500 000. (Данные имеют выбросы: с 4 по 8 километр цена на квартиры больше чем ожидается и на 27 километре в силу малого количества данных (всего 2 обьявления) имеется цена больше ожидаемой)
#
# ### Рекомендации
#
# #### Параметры, на которые стоит обращать внимание при оценке рыночной стоимости квартиры:
#
# * количество комнат,
# * населенный пункт,
# * этаж,
# * общая площадь,
# * жилая площадь,
# * площадь кухни,
# * расстояние до центра города
#
# #### Скорость продажи квартиры:
#
# * квартира обычно пробается за 45-222 дней.
#
# #### Как можно улучшить анализ этих данных:
#
# * в первую очередь заполнить пропуски в колонках:
#     * жилой площади (9% данных утеряно),
#     * площадью кухни (10% данных утеряно),
#     * airports_nearest, cityCenters_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest(от 20% до 50% данных утеряно в конеретных населенных пунктах)

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Технически вывод хороший, есть сравнения показателей, инсайты, анализ рынка недвижимости, молодец
#
# Осталось перепроверить итоговый вывод после исправления всех комментариев

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Выполнил исследовательскую работу, молодец
#
# Критические ❌ комментарии
#
#
# + проверить корректность заполнения пропусков синтетическими данными
# + настроить фильтрацию редких значений
# + подправить гистограммы в п.4.1
# + пересчитать скорость продаж
# + добавить вывод в п. 4.3
# + добавить график в ТОП-10
# + исследовать аномалии в п.4.5
# + поправить итоговый вывод
#
#
#
# С ними важно поработать и исправить
#
# Стоит обратить внимание и на такие комментарии ⚠️
#
# Если будут вопросы про мои комментарии - задавай, если какой-то формат взаимодействия не устраивает или есть какие-то другие пожелания - пиши :)
#
# <div class="alert alert-success">
#     <font size="5"><b>Жду твой проект и твои комментарии 🤝</b></font><br />
#
# нумерация пунктов из брифа проекта, у тебя они могут быть другие
#
# если не заметил твоих вопросов, просьба выделить цветом
#
#
# __Для успешного исправления комментариев стоит прочитать справочные материалы ⬇⬇⬇__

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />
#
# [Обработка пропусков в данных](https://loginom.ru/blog/missing)
#
#
# [Подробное руководство по группировке и агрегированию с помощью pandas](https://dfedorov.spb.ru/pandas/%D0%9F%D0%BE%D0%B4%D1%80%D0%BE%D0%B1%D0%BD%D0%BE%D0%B5%20%D1%80%D1%83%D0%BA%D0%BE%D0%B2%D0%BE%D0%B4%D1%81%D1%82%D0%B2%D0%BE%20%D0%BF%D0%BE%20%D0%B3%D1%80%D1%83%D0%BF%D0%BF%D0%B8%D1%80%D0%BE%D0%B2%D0%BA%D0%B5%20%D0%B8%20%D0%B0%D0%B3%D1%80%D0%B5%D0%B3%D0%B8%D1%80%D0%BE%D0%B2%D0%B0%D0%BD%D0%B8%D1%8E%20%D1%81%20%D0%BF%D0%BE%D0%BC%D0%BE%D1%89%D1%8C%D1%8E%20pandas.html)
#
# [Сводная таблица в pandas](https://dfedorov.spb.ru/pandas/%D0%A1%D0%B2%D0%BE%D0%B4%D0%BD%D0%B0%D1%8F%20%D1%82%D0%B0%D0%B1%D0%BB%D0%B8%D1%86%D0%B0%20%D0%B2%20pandas.html?ysclid=lje9wz2vfc28794921)
#
# [Понимание функции transform в Pandas](https://dfedorov.spb.ru/pandas/%D0%9F%D0%BE%D0%BD%D0%B8%D0%BC%D0%B0%D0%BD%D0%B8%D0%B5%20%D1%84%D1%83%D0%BD%D0%BA%D1%86%D0%B8%D0%B8%20transform%20%D0%B2%20Pandas.html)
#
# [Как выбрать определенные столбцы из DataFrame](https://dfedorov.spb.ru/pandas/03.%20%D0%9A%D0%B0%D0%BA%20%D0%B2%D1%8B%D0%B1%D1%80%D0%B0%D1%82%D1%8C%20%D0%BF%D0%BE%D0%B4%D0%BC%D0%BD%D0%BE%D0%B6%D0%B5%D1%81%D1%82%D0%B2%D0%BE%20%D0%B8%D0%B7%20DataFrame_.html?ysclid=l9sps5lt6g576766938)
#
# [How to visualise data using histograms in Pandas](https://practicaldatascience.co.uk/data-science/how-to-visualise-data-using-histograms-in-pandas)
#
# [8 способов фильтрации фреймов данных Pandas](https://questu.ru/articles/85248/)
